# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Loading Datasets on to DataFrames
indicators_url = 'https://github.com/chc5/education-indicator-analysis/raw/master/2018_all_indicators.csv'
education_url = 'https://github.com/chc5/education-indicator-analysis/raw/master/adult_education_level.csv'

inds_df = pd.read_csv(indicators_url)
ed_df = pd.read_csv(education_url)

# Column 9999 in the Indicators Dataset only shows the latest value from the data drawn within 1990 to 2017.
# In order to detect education system growth predictors this column is unneccessary.
inds_df = inds_df.drop(columns=['9999'])

# %%
# Many indicators from 1990 to 2017 that only have at most one or two recordings for a specific indicators.
# These recordings may or may not indicate growth over the years which will not contribute to our analysis.
# These indicators will be dropped.
# When threshold = 1, it removed 25636 - 20588 = 5048 / 25636 = 20% of the indicators
threshold = 20
drop_stack = set()
print(len(inds_df))
for index, row in inds_df.iterrows():
#     print(row['1990':].count())
    if row['1990':].count() <= threshold:
        drop_stack.add(index)
inds_df = inds_df.drop(drop_stack)
print(len(inds_df))
# Out:
# 25636
# 6242

# %%
# Get the missing values at each year and return the array of years (aka. column)
def get_missing_yearly_values(row):
    row_df = row.to_frame().reset_index()
    row_df = row_df.drop(range(5))
    row_df.columns = ['x', 'y']
    missing_X = row_df[row_df['y'].isnull()].x
    return missing_X

# Predicting the missing values using Linear Regression Models
# and then filling out the missing values based on the model
year_columns = inds_df.columns.values[5:]
for index, row in inds_df.iterrows():
    missing_years = get_missing_yearly_values(row).values
    # If there are nothing to fill out then we don't need to model it out.
    if missing_years.size <= 0:
        continue
    row = row.drop(missing_years)
    row = row.drop(['dimension', 'indicator_id', 'indicator_name', 'iso3', 'country_name'])
    value = row.values.reshape(-1, 1)
    year = year_columns
    # The difference set of total years and missing years are the years where there are recorded values.
    year = np.setdiff1d(year, missing_years).astype(int).reshape(-1, 1)
    missing_years = missing_years.astype(int)
    missing_years = missing_years.reshape(missing_years.shape[0],-1)
    
    reg = LinearRegression()
    reg.fit(year, value)
    missing_values = reg.predict(missing_years)
    # Filling out the missing data
    for i in range(len(missing_years)):
        inds_df.at[index, str(missing_years[i][0])] = missing_values[i][0]

# %%
def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns);
    plt.yticks(range(len(corr.columns)), corr.columns);
    
country_names = inds_df.country_name.unique()
  
def plot_corr_country(df, country):
  # drop ids etc., get only rows with country, transpose
  df_corr = inds_df.drop(df.columns[[0, 1, 3]], axis=1)[df.country_name == country].T
  # fix columns
  df_corr.columns = df_corr.iloc[0]
  # drop first two rops
  df_corr = df_corr[2:]
  # df_corr = inds_df.drop(inds_df.columns[[0, 1, 3]], axis=1).drop(inds_df.columns[range(5,32)], axis=1)[inds_df.country_name == "Albania"]
  df_corr = df_corr.apply(pd.to_numeric)
  plot_corr(df_corr, size=20)
  return df_corr

# change threshold to get more columns 
df_corr = plot_corr_country(inds_df, "United States")

# %%
def strongest_indicators(df_corr, num_indicators):
    possible_strongest = []
    for row in df_corr.corr():
        #corr_dict.update(row = df_corr.corr()[row])
        possible_strongest.append([row, df_corr.corr()[row]['Education index']])
        possible_strongest.sort(key = 
                                    lambda corr: corr[1])
    #gets rid of the correlation with the same feature
    possible_strongest = possible_strongest[:-1]
    return possible_strongest[len(possible_strongest)-num_indicators:len(possible_strongest)]

potential_indicators = strongest_indicators(df_corr, 10)

def check_corr(df_corr, potential_indicators, target_feature):
    features_ex = [indicator[0] for indicator in potential_indicators]
    features_ex.remove(target_feature)
    for feature in features_ex:
        if df_corr.corr()[target_feature][feature] > 0.95:
            return False
    return True

potential_ret_val = []
for indicator_pair in potential_indicators:
    potential_ret_val.append(check_corr(df_corr, potential_indicators, indicator_pair[0]))
print(potential_ret_val)

#def check_independence(potential_indicators):

# %%
df_corr.corr()
# Out:
# indicator_name                                      Human Development Index (HDI)  \
# indicator_name
# Human Development Index (HDI)                                            1.000000
# Old-age (65 and older) dependency ratio (per 10...                       0.561934
# Population ages 15–64 (millions)                                         0.988785
# Population ages 65 and older (millions)                                  0.905013
# Population under age 5 (millions)                                        0.491210
# Total population (millions)                                              0.992437
# Urban population (%)                                                     0.979007
# Young age (0-14) dependency ratio (per 100 peop...                      -0.948025
# Education index                                                          0.956854
# Expected years of schooling (years)                                      0.927807
# Expected years of schooling, female (years)                              0.930025
# Expected years of schooling, male (years)                                0.842888
# Mean years of schooling (years)                                          0.964931
# Mean years of schooling, female (years)                                  0.942395
# Mean years of schooling, male (years)                                    0.976217
# Population with at least some secondary educati...                       0.983587
# Population with at least some secondary educati...                       0.652758
# Share of seats in parliament (% held by women)                           0.985356
# Infants lacking immunization, DPT (% of one-yea...                      -0.195271
# Infants lacking immunization, measles (% of one...                      -0.625500
# Life expectancy at birth (years)                                         0.994064
# Life expectancy at birth, female (years)                                 0.984631
# Life expectancy at birth, male (years)                                   0.992592
# Life expectancy index                                                    0.995283
# Mortality rate, female adult (per 1,000 people)                         -0.963561
# Mortality rate, infant (per 1,000 live births)                          -0.971364
# Mortality rate, male adult (per 1,000 people)                           -0.943068
# Mortality rate, under-five (per 1,000 live births)                      -0.973892
# Gross national income (GNI) per capita (2011 PP...                       0.959559
# Income index                                                             0.955214
# International inbound tourists (thousands)                               0.937729
# Exports and imports (% of GDP)                                           0.926766
# Foreign direct investment, net inflows (% of GDP)                        0.515629
# Private capital flows (% of GDP)                                        -0.180500
# Remittances, inflows (% of GDP)                                          0.712734
#
# indicator_name                                      Old-age (65 and older) dependency ratio (per 100 people ages 15-64)  \
# indicator_name
# Human Development Index (HDI)                                                                0.561934
# Old-age (65 and older) dependency ratio (per 10...                                           1.000000
# Population ages 15–64 (millions)                                                             0.503312
# Population ages 65 and older (millions)                                                      0.852551
# Population under age 5 (millions)                                                           -0.172902
# Total population (millions)                                                                  0.563382
# Urban population (%)                                                                         0.488395
# Young age (0-14) dependency ratio (per 100 peop...                                          -0.648901
# Education index                                                                              0.601153
# Expected years of schooling (years)                                                          0.555902
# Expected years of schooling, female (years)                                                  0.457335
# Expected years of schooling, male (years)                                                    0.632865
# Mean years of schooling (years)                                                              0.666447
# Mean years of schooling, female (years)                                                      0.669239
# Mean years of schooling, male (years)                                                        0.556186
# Population with at least some secondary educati...                                           0.657209
# Population with at least some secondary educati...                                           0.206849
# Share of seats in parliament (% held by women)                                               0.578922
# Infants lacking immunization, DPT (% of one-yea...                                           0.246796
# Infants lacking immunization, measles (% of one...                                          -0.095040
# Life expectancy at birth (years)                                                             0.592739
# Life expectancy at birth, female (years)                                                     0.671352
# Life expectancy at birth, male (years)                                                       0.553004
# Life expectancy index                                                                        0.595330
# Mortality rate, female adult (per 1,000 people)                                             -0.450017
# Mortality rate, infant (per 1,000 live births)                                              -0.515161
# Mortality rate, male adult (per 1,000 people)                                               -0.448634
# Mortality rate, under-five (per 1,000 live births)                                          -0.519880
# Gross national income (GNI) per capita (2011 PP...                                           0.446016
# Income index                                                                                 0.418747
# International inbound tourists (thousands)                                                   0.732853
# Exports and imports (% of GDP)                                                               0.485950
# Foreign direct investment, net inflows (% of GDP)                                            0.199689
# Private capital flows (% of GDP)                                                             0.398810
# Remittances, inflows (% of GDP)                                                             -0.016595
#
# indicator_name                                      Population ages 15–64 (millions)  \
# indicator_name
# Human Development Index (HDI)                                               0.988785
# Old-age (65 and older) dependency ratio (per 10...                          0.503312
# Population ages 15–64 (millions)                                            1.000000
# Population ages 65 and older (millions)                                     0.880536
# Population under age 5 (millions)                                           0.465118
# Total population (millions)                                                 0.996834
# Urban population (%)                                                        0.986647
# Young age (0-14) dependency ratio (per 100 peop...                         -0.956143
# Education index                                                             0.909749
# Expected years of schooling (years)                                         0.874412
# Expected years of schooling, female (years)                                 0.890080
# Expected years of schooling, male (years)                                   0.774724
# Mean years of schooling (years)                                             0.924057
# Mean years of schooling, female (years)                                     0.901742
# Mean years of schooling, male (years)                                       0.969296
# Population with at least some secondary educati...                          0.968220
# Population with at least some secondary educati...                          0.606641
# Share of seats in parliament (% held by women)                              0.988867
# Infants lacking immunization, DPT (% of one-yea...                         -0.199730
# Infants lacking immunization, measles (% of one...                         -0.661470
# Life expectancy at birth (years)                                            0.993434
# Life expectancy at birth, female (years)                                    0.972138
# Life expectancy at birth, male (years)                                      0.996439
# Life expectancy index                                                       0.992871
# Mortality rate, female adult (per 1,000 people)                            -0.966845
# Mortality rate, infant (per 1,000 live births)                             -0.968157
# Mortality rate, male adult (per 1,000 people)                              -0.955868
# Mortality rate, under-five (per 1,000 live births)                         -0.971375
# Gross national income (GNI) per capita (2011 PP...                          0.981584
# Income index                                                                0.978036
# International inbound tourists (thousands)                                  0.909747
# Exports and imports (% of GDP)                                              0.908615
# Foreign direct investment, net inflows (% of GDP)                           0.524954
# Private capital flows (% of GDP)                                           -0.235928
# Remittances, inflows (% of GDP)                                             0.750528
#
# indicator_name                                      Population ages 65 and older (millions)  \
# indicator_name
# Human Development Index (HDI)                                                      0.905013
# Old-age (65 and older) dependency ratio (per 10...                                 0.852551
# Population ages 15–64 (millions)                                                   0.880536
# Population ages 65 and older (millions)                                            1.000000
# Population under age 5 (millions)                                                  0.179633
# Total population (millions)                                                        0.911636
# Urban population (%)                                                               0.864750
# Young age (0-14) dependency ratio (per 100 peop...                                -0.933704
# Education index                                                                    0.876553
# Expected years of schooling (years)                                                0.830116
# Expected years of schooling, female (years)                                        0.785848
# Expected years of schooling, male (years)                                          0.811157
# Mean years of schooling (years)                                                    0.921402
# Mean years of schooling, female (years)                                            0.909656
# Mean years of schooling, male (years)                                              0.890469
# Population with at least some secondary educati...                                 0.944572
# Population with at least some secondary educati...                                 0.478370
# Share of seats in parliament (% held by women)                                     0.915071
# Infants lacking immunization, DPT (% of one-yea...                                 0.013736
# Infants lacking immunization, measles (% of one...                                -0.456403
# Life expectancy at birth (years)                                                   0.925331
# Life expectancy at birth, female (years)                                           0.954891
# Life expectancy at birth, male (years)                                             0.905691
# Life expectancy index                                                              0.926328
# Mortality rate, female adult (per 1,000 people)                                   -0.831196
# Mortality rate, infant (per 1,000 live births)                                    -0.868183
# Mortality rate, male adult (per 1,000 people)                                     -0.825193
# Mortality rate, under-five (per 1,000 live births)                                -0.872782
# Gross national income (GNI) per capita (2011 PP...                                 0.839361
# Income index                                                                       0.822314
# International inbound tourists (thousands)                                         0.950727
# Exports and imports (% of GDP)                                                     0.814216
# Foreign direct investment, net inflows (% of GDP)                                  0.428335
# Private capital flows (% of GDP)                                                   0.071437
# Remittances, inflows (% of GDP)                                                    0.445198
#
# indicator_name                                      Population under age 5 (millions)  \
# indicator_name
# Human Development Index (HDI)                                                0.491210
# Old-age (65 and older) dependency ratio (per 10...                          -0.172902
# Population ages 15–64 (millions)                                             0.465118
# Population ages 65 and older (millions)                                      0.179633
# Population under age 5 (millions)                                            1.000000
# Total population (millions)                                                  0.422118
# Urban population (%)                                                         0.414675
# Young age (0-14) dependency ratio (per 100 peop...                          -0.387999
# Education index                                                              0.557484
# Expected years of schooling (years)                                          0.616266
# Expected years of schooling, female (years)                                  0.672669
# Expected years of schooling, male (years)                                    0.551996
# Mean years of schooling (years)                                              0.464210
# Mean years of schooling, female (years)                                      0.450726
# Mean years of schooling, male (years)                                        0.390948
# Population with at least some secondary educati...                           0.423164
# Population with at least some secondary educati...                           0.349347
# Share of seats in parliament (% held by women)                               0.431671
# Infants lacking immunization, DPT (% of one-yea...                          -0.174683
# Infants lacking immunization, measles (% of one...                          -0.231269
# Life expectancy at birth (years)                                             0.430425
# Life expectancy at birth, female (years)                                     0.422147
# Life expectancy at birth, male (years)                                       0.427979
# Life expectancy index                                                        0.433713
# Mortality rate, female adult (per 1,000 people)                             -0.482730
# Mortality rate, infant (per 1,000 live births)                              -0.382883
# Mortality rate, male adult (per 1,000 people)                               -0.367510
# Mortality rate, under-five (per 1,000 live births)                          -0.383754
# Gross national income (GNI) per capita (2011 PP...                           0.425557
# Income index                                                                 0.429605
# International inbound tourists (thousands)                                   0.302398
# Exports and imports (% of GDP)                                               0.564758
# Foreign direct investment, net inflows (% of GDP)                            0.128006
# Private capital flows (% of GDP)                                            -0.263647
# Remittances, inflows (% of GDP)                                              0.439301
#
# indicator_name                                      Total population (millions)  \
# indicator_name
# Human Development Index (HDI)                                          0.992437
# Old-age (65 and older) dependency ratio (per 10...                     0.563382
# Population ages 15–64 (millions)                                       0.996834
# Population ages 65 and older (millions)                                0.911636
# Population under age 5 (millions)                                      0.422118
# Total population (millions)                                            1.000000
# Urban population (%)                                                   0.988437
# Young age (0-14) dependency ratio (per 100 peop...                    -0.959376
# Education index                                                        0.919131
# Expected years of schooling (years)                                    0.880560
# Expected years of schooling, female (years)                            0.886611
# Expected years of schooling, male (years)                              0.788580
# Mean years of schooling (years)                                        0.939071
# Mean years of schooling, female (years)                                0.916237
# Mean years of schooling, male (years)                                  0.975431
# Population with at least some secondary educati...                     0.979689
# Population with at least some secondary educati...                     0.621312
# Share of seats in parliament (% held by women)                         0.992561
# Infants lacking immunization, DPT (% of one-yea...                    -0.191976
# Infants lacking immunization, measles (% of one...                    -0.649069
# Life expectancy at birth (years)                                       0.998305
# Life expectancy at birth, female (years)                               0.982276
# Life expectancy at birth, male (years)                                 0.999509
# Life expectancy index                                                  0.998166
# Mortality rate, female adult (per 1,000 people)                       -0.964438
# Mortality rate, infant (per 1,000 live births)                        -0.975982
# Mortality rate, male adult (per 1,000 people)                         -0.957106
# Mortality rate, under-five (per 1,000 live births)                    -0.978990
# Gross national income (GNI) per capita (2011 PP...                     0.977276
# Income index                                                           0.972589
# International inbound tourists (thousands)                             0.933381
# Exports and imports (% of GDP)                                         0.907004
# Foreign direct investment, net inflows (% of GDP)                      0.531209
# Private capital flows (% of GDP)                                      -0.201063
# Remittances, inflows (% of GDP)                                        0.724490
#
# indicator_name                                      Urban population (%)  \
# indicator_name
# Human Development Index (HDI)                                   0.979007
# Old-age (65 and older) dependency ratio (per 10...              0.488395
# Population ages 15–64 (millions)                                0.986647
# Population ages 65 and older (millions)                         0.864750
# Population under age 5 (millions)                               0.414675
# Total population (millions)                                     0.988437
# Urban population (%)                                            1.000000
# Young age (0-14) dependency ratio (per 100 peop...             -0.907346
# Education index                                                 0.888890
# Expected years of schooling (years)                             0.848864
# Expected years of schooling, female (years)                     0.862107
# Expected years of schooling, male (years)                       0.733341
# Mean years of schooling (years)                                 0.909075
# Mean years of schooling, female (years)                         0.876706
# Mean years of schooling, male (years)                           0.968818
# Population with at least some secondary educati...              0.953344
# Population with at least some secondary educati...              0.708959
# Share of seats in parliament (% held by women)                  0.976122
# Infants lacking immunization, DPT (% of one-yea...             -0.305334
# Infants lacking immunization, measles (% of one...             -0.702812
# Life expectancy at birth (years)                                0.980300
# Life expectancy at birth, female (years)                        0.947179
# Life expectancy at birth, male (years)                          0.991681
# Life expectancy index                                           0.980355
# Mortality rate, female adult (per 1,000 people)                -0.969691
# Mortality rate, infant (per 1,000 live births)                 -0.993738
# Mortality rate, male adult (per 1,000 people)                  -0.974603
# Mortality rate, under-five (per 1,000 live births)             -0.995101
# Gross national income (GNI) per capita (2011 PP...              0.984923
# Income index                                                    0.985889
# International inbound tourists (thousands)                      0.910559
# Exports and imports (% of GDP)                                  0.886372
# Foreign direct investment, net inflows (% of GDP)               0.584027
# Private capital flows (% of GDP)                               -0.285873
# Remittances, inflows (% of GDP)                                 0.787877
#
# indicator_name                                      Young age (0-14) dependency ratio (per 100 people ages 15-64)  \
# indicator_name
# Human Development Index (HDI)                                                               -0.948025
# Old-age (65 and older) dependency ratio (per 10...                                          -0.648901
# Population ages 15–64 (millions)                                                            -0.956143
# Population ages 65 and older (millions)                                                     -0.933704
# Population under age 5 (millions)                                                           -0.387999
# Total population (millions)                                                                 -0.959376
# Urban population (%)                                                                        -0.907346
# Young age (0-14) dependency ratio (per 100 peop...                                           1.000000
# Education index                                                                             -0.889933
# Expected years of schooling (years)                                                         -0.855877
# Expected years of schooling, female (years)                                                 -0.852338
# Expected years of schooling, male (years)                                                   -0.804298
# Mean years of schooling (years)                                                             -0.912947
# Mean years of schooling, female (years)                                                     -0.907774
# Mean years of schooling, male (years)                                                       -0.917336
# Population with at least some secondary educati...                                          -0.958053
# Population with at least some secondary educati...                                          -0.396565
# Share of seats in parliament (% held by women)                                              -0.963314
# Infants lacking immunization, DPT (% of one-yea...                                          -0.015792
# Infants lacking immunization, measles (% of one...                                           0.528540
# Life expectancy at birth (years)                                                            -0.967971
# Life expectancy at birth, female (years)                                                    -0.979730
# Life expectancy at birth, male (years)                                                      -0.951923
# Life expectancy index                                                                       -0.966559
# Mortality rate, female adult (per 1,000 people)                                              0.892935
# Mortality rate, infant (per 1,000 live births)                                               0.878276
# Mortality rate, male adult (per 1,000 people)                                                0.866011
# Mortality rate, under-five (per 1,000 live births)                                           0.885005
# Gross national income (GNI) per capita (2011 PP...                                          -0.914872
# Income index                                                                                -0.899777
# International inbound tourists (thousands)                                                  -0.906292
# Exports and imports (% of GDP)                                                              -0.878455
# Foreign direct investment, net inflows (% of GDP)                                           -0.414378
# Private capital flows (% of GDP)                                                             0.066765
# Remittances, inflows (% of GDP)                                                             -0.574736
#
# indicator_name                                      Education index  \
# indicator_name
# Human Development Index (HDI)                              0.956854
# Old-age (65 and older) dependency ratio (per 10...         0.601153
# Population ages 15–64 (millions)                           0.909749
# Population ages 65 and older (millions)                    0.876553
# Population under age 5 (millions)                          0.557484
# Total population (millions)                                0.919131
# Urban population (%)                                       0.888890
# Young age (0-14) dependency ratio (per 100 peop...        -0.889933
# Education index                                            1.000000
# Expected years of schooling (years)                        0.987044
# Expected years of schooling, female (years)                0.971875
# Expected years of schooling, male (years)                  0.945397
# Mean years of schooling (years)                            0.984888
# Mean years of schooling, female (years)                    0.969629
# Mean years of schooling, male (years)                      0.930504
# Population with at least some secondary educati...         0.947348
# Population with at least some secondary educati...         0.640067
# Share of seats in parliament (% held by women)             0.910758
# Infants lacking immunization, DPT (% of one-yea...        -0.091847
# Infants lacking immunization, measles (% of one...        -0.480923
# Life expectancy at birth (years)                           0.931478
# Life expectancy at birth, female (years)                   0.948197
# Life expectancy at birth, male (years)                     0.918148
# Life expectancy index                                      0.935069
# Mortality rate, female adult (per 1,000 people)           -0.886199
# Mortality rate, infant (per 1,000 live births)            -0.893926
# Mortality rate, male adult (per 1,000 people)             -0.842978
# Mortality rate, under-five (per 1,000 live births)        -0.895730
# Gross national income (GNI) per capita (2011 PP...         0.839075
# Income index                                               0.832772
# International inbound tourists (thousands)                 0.907660
# Exports and imports (% of GDP)                             0.896665
# Foreign direct investment, net inflows (% of GDP)          0.389217
# Private capital flows (% of GDP)                          -0.008419
# Remittances, inflows (% of GDP)                            0.596206
#
# indicator_name                                      Expected years of schooling (years)  \
# indicator_name
# Human Development Index (HDI)                                                  0.927807
# Old-age (65 and older) dependency ratio (per 10...                             0.555902
# Population ages 15–64 (millions)                                               0.874412
# Population ages 65 and older (millions)                                        0.830116
# Population under age 5 (millions)                                              0.616266
# Total population (millions)                                                    0.880560
# Urban population (%)                                                           0.848864
# Young age (0-14) dependency ratio (per 100 peop...                            -0.855877
# Education index                                                                0.987044
# Expected years of schooling (years)                                            1.000000
# Expected years of schooling, female (years)                                    0.985689
# Expected years of schooling, male (years)                                      0.951344
# Mean years of schooling (years)                                                0.950751
# Mean years of schooling, female (years)                                        0.935056
# Mean years of schooling, male (years)                                          0.878993
# Population with at least some secondary educati...                             0.909107
# Population with at least some secondary educati...                             0.621130
# Share of seats in parliament (% held by women)                                 0.872614
# Infants lacking immunization, DPT (% of one-yea...                            -0.081481
# Infants lacking immunization, measles (% of one...                            -0.448862
# Life expectancy at birth (years)                                               0.895501
# Life expectancy at birth, female (years)                                       0.915034
# Life expectancy at birth, male (years)                                         0.880055
# Life expectancy index                                                          0.899386
# Mortality rate, female adult (per 1,000 people)                               -0.852101
# Mortality rate, infant (per 1,000 live births)                                -0.851314
# Mortality rate, male adult (per 1,000 people)                                 -0.791868
# Mortality rate, under-five (per 1,000 live births)                            -0.853224
# Gross national income (GNI) per capita (2011 PP...                             0.803571
# Income index                                                                   0.796816
# International inbound tourists (thousands)                                     0.856026
# Exports and imports (% of GDP)                                                 0.867867
# Foreign direct investment, net inflows (% of GDP)                              0.339689
# Private capital flows (% of GDP)                                               0.002487
# Remittances, inflows (% of GDP)                                                0.576593
#
# indicator_name                                                   ...                 \
# indicator_name                                                   ...
# Human Development Index (HDI)                                    ...
# Old-age (65 and older) dependency ratio (per 10...               ...
# Population ages 15–64 (millions)                                 ...
# Population ages 65 and older (millions)                          ...
# Population under age 5 (millions)                                ...
# Total population (millions)                                      ...
# Urban population (%)                                             ...
# Young age (0-14) dependency ratio (per 100 peop...               ...
# Education index                                                  ...
# Expected years of schooling (years)                              ...
# Expected years of schooling, female (years)                      ...
# Expected years of schooling, male (years)                        ...
# Mean years of schooling (years)                                  ...
# Mean years of schooling, female (years)                          ...
# Mean years of schooling, male (years)                            ...
# Population with at least some secondary educati...               ...
# Population with at least some secondary educati...               ...
# Share of seats in parliament (% held by women)                   ...
# Infants lacking immunization, DPT (% of one-yea...               ...
# Infants lacking immunization, measles (% of one...               ...
# Life expectancy at birth (years)                                 ...
# Life expectancy at birth, female (years)                         ...
# Life expectancy at birth, male (years)                           ...
# Life expectancy index                                            ...
# Mortality rate, female adult (per 1,000 people)                  ...
# Mortality rate, infant (per 1,000 live births)                   ...
# Mortality rate, male adult (per 1,000 people)                    ...
# Mortality rate, under-five (per 1,000 live births)               ...
# Gross national income (GNI) per capita (2011 PP...               ...
# Income index                                                     ...
# International inbound tourists (thousands)                       ...
# Exports and imports (% of GDP)                                   ...
# Foreign direct investment, net inflows (% of GDP)                ...
# Private capital flows (% of GDP)                                 ...
# Remittances, inflows (% of GDP)                                  ...
#
# indicator_name                                      Mortality rate, infant (per 1,000 live births)  \
# indicator_name
# Human Development Index (HDI)                                                            -0.971364
# Old-age (65 and older) dependency ratio (per 10...                                       -0.515161
# Population ages 15–64 (millions)                                                         -0.968157
# Population ages 65 and older (millions)                                                  -0.868183
# Population under age 5 (millions)                                                        -0.382883
# Total population (millions)                                                              -0.975982
# Urban population (%)                                                                     -0.993738
# Young age (0-14) dependency ratio (per 100 peop...                                        0.878276
# Education index                                                                          -0.893926
# Expected years of schooling (years)                                                      -0.851314
# Expected years of schooling, female (years)                                              -0.857903
# Expected years of schooling, male (years)                                                -0.739510
# Mean years of schooling (years)                                                          -0.913963
# Mean years of schooling, female (years)                                                  -0.881620
# Mean years of schooling, male (years)                                                    -0.967563
# Population with at least some secondary educati...                                       -0.948080
# Population with at least some secondary educati...                                       -0.761938
# Share of seats in parliament (% held by women)                                           -0.959916
# Infants lacking immunization, DPT (% of one-yea...                                        0.329469
# Infants lacking immunization, measles (% of one...                                        0.701064
# Life expectancy at birth (years)                                                         -0.967889
# Life expectancy at birth, female (years)                                                 -0.935908
# Life expectancy at birth, male (years)                                                   -0.980462
# Life expectancy index                                                                    -0.968946
# Mortality rate, female adult (per 1,000 people)                                           0.960314
# Mortality rate, infant (per 1,000 live births)                                            1.000000
# Mortality rate, male adult (per 1,000 people)                                             0.972520
# Mortality rate, under-five (per 1,000 live births)                                        0.999596
# Gross national income (GNI) per capita (2011 PP...                                       -0.965223
# Income index                                                                             -0.967640
# International inbound tourists (thousands)                                               -0.919800
# Exports and imports (% of GDP)                                                           -0.880151
# Foreign direct investment, net inflows (% of GDP)                                        -0.587600
# Private capital flows (% of GDP)                                                          0.262294
# Remittances, inflows (% of GDP)                                                          -0.768717
#
# indicator_name                                      Mortality rate, male adult (per 1,000 people)  \
# indicator_name
# Human Development Index (HDI)                                                           -0.943068
# Old-age (65 and older) dependency ratio (per 10...                                      -0.448634
# Population ages 15–64 (millions)                                                        -0.955868
# Population ages 65 and older (millions)                                                 -0.825193
# Population under age 5 (millions)                                                       -0.367510
# Total population (millions)                                                             -0.957106
# Urban population (%)                                                                    -0.974603
# Young age (0-14) dependency ratio (per 100 peop...                                       0.866011
# Education index                                                                         -0.842978
# Expected years of schooling (years)                                                     -0.791868
# Expected years of schooling, female (years)                                             -0.823882
# Expected years of schooling, male (years)                                               -0.648065
# Mean years of schooling (years)                                                         -0.865568
# Mean years of schooling, female (years)                                                 -0.859661
# Mean years of schooling, male (years)                                                   -0.947552
# Population with at least some secondary educati...                                      -0.913627
# Population with at least some secondary educati...                                      -0.676487
# Share of seats in parliament (% held by women)                                          -0.928748
# Infants lacking immunization, DPT (% of one-yea...                                       0.325825
# Infants lacking immunization, measles (% of one...                                       0.740832
# Life expectancy at birth (years)                                                        -0.944856
# Life expectancy at birth, female (years)                                                -0.904804
# Life expectancy at birth, male (years)                                                  -0.960197
# Life expectancy index                                                                   -0.945209
# Mortality rate, female adult (per 1,000 people)                                          0.983235
# Mortality rate, infant (per 1,000 live births)                                           0.972520
# Mortality rate, male adult (per 1,000 people)                                            1.000000
# Mortality rate, under-five (per 1,000 live births)                                       0.971990
# Gross national income (GNI) per capita (2011 PP...                                      -0.961089
# Income index                                                                            -0.965124
# International inbound tourists (thousands)                                              -0.875912
# Exports and imports (% of GDP)                                                          -0.860146
# Foreign direct investment, net inflows (% of GDP)                                       -0.626106
# Private capital flows (% of GDP)                                                         0.314916
# Remittances, inflows (% of GDP)                                                         -0.752097
#
# indicator_name                                      Mortality rate, under-five (per 1,000 live births)  \
# indicator_name
# Human Development Index (HDI)                                                               -0.973892
# Old-age (65 and older) dependency ratio (per 10...                                          -0.519880
# Population ages 15–64 (millions)                                                            -0.971375
# Population ages 65 and older (millions)                                                     -0.872782
# Population under age 5 (millions)                                                           -0.383754
# Total population (millions)                                                                 -0.978990
# Urban population (%)                                                                        -0.995101
# Young age (0-14) dependency ratio (per 100 peop...                                           0.885005
# Education index                                                                             -0.895730
# Expected years of schooling (years)                                                         -0.853224
# Expected years of schooling, female (years)                                                 -0.859466
# Expected years of schooling, male (years)                                                   -0.743673
# Mean years of schooling (years)                                                             -0.916524
# Mean years of schooling, female (years)                                                     -0.883365
# Mean years of schooling, male (years)                                                       -0.969661
# Population with at least some secondary educati...                                          -0.950655
# Population with at least some secondary educati...                                          -0.753581
# Share of seats in parliament (% held by women)                                              -0.964012
# Infants lacking immunization, DPT (% of one-yea...                                           0.323570
# Infants lacking immunization, measles (% of one...                                           0.697407
# Life expectancy at birth (years)                                                            -0.971335
# Life expectancy at birth, female (years)                                                    -0.940208
# Life expectancy at birth, male (years)                                                      -0.983393
# Life expectancy index                                                                       -0.972180
# Mortality rate, female adult (per 1,000 people)                                              0.961111
# Mortality rate, infant (per 1,000 live births)                                               0.999596
# Mortality rate, male adult (per 1,000 people)                                                0.971990
# Mortality rate, under-five (per 1,000 live births)                                           1.000000
# Gross national income (GNI) per capita (2011 PP...                                          -0.968237
# ...
# Expected years of schooling, female (years)                                           0.828967
# Expected years of schooling, male (years)                                             0.806667
# Mean years of schooling (years)                                                       0.942556
# Mean years of schooling, female (years)                                               0.936528
# Mean years of schooling, male (years)                                                 0.932453
# Population with at least some secondary educati...                                    0.968299
# Population with at least some secondary educati...                                    0.629689
# Share of seats in parliament (% held by women)                                        0.937357
# Infants lacking immunization, DPT (% of one-yea...                                   -0.174344
# Infants lacking immunization, measles (% of one...                                   -0.556753
# Life expectancy at birth (years)                                                      0.941661
# Life expectancy at birth, female (years)                                              0.953871
# Life expectancy at birth, male (years)                                                0.931016
# Life expectancy index                                                                 0.943422
# Mortality rate, female adult (per 1,000 people)                                      -0.874696
# Mortality rate, infant (per 1,000 live births)                                       -0.919800
# Mortality rate, male adult (per 1,000 people)                                        -0.875912
# Mortality rate, under-five (per 1,000 live births)                                   -0.921082
# Gross national income (GNI) per capita (2011 PP...                                    0.878518
# Income index                                                                          0.870673
# International inbound tourists (thousands)                                            1.000000
# Exports and imports (% of GDP)                                                        0.892455
# Foreign direct investment, net inflows (% of GDP)                                     0.578930
# Private capital flows (% of GDP)                                                     -0.055360
# Remittances, inflows (% of GDP)                                                       0.577470
#
# indicator_name                                      Exports and imports (% of GDP)  \
# indicator_name
# Human Development Index (HDI)                                             0.926766
# Old-age (65 and older) dependency ratio (per 10...                        0.485950
# Population ages 15–64 (millions)                                          0.908615
# Population ages 65 and older (millions)                                   0.814216
# Population under age 5 (millions)                                         0.564758
# Total population (millions)                                               0.907004
# Urban population (%)                                                      0.886372
# Young age (0-14) dependency ratio (per 100 peop...                       -0.878455
# Education index                                                           0.896665
# Expected years of schooling (years)                                       0.867867
# Expected years of schooling, female (years)                               0.877326
# Expected years of schooling, male (years)                                 0.795373
# Mean years of schooling (years)                                           0.896398
# Mean years of schooling, female (years)                                   0.894402
# Mean years of schooling, male (years)                                     0.897228
# Population with at least some secondary educati...                        0.918616
# Population with at least some secondary educati...                        0.582621
# Share of seats in parliament (% held by women)                            0.910179
# Infants lacking immunization, DPT (% of one-yea...                       -0.221381
# Infants lacking immunization, measles (% of one...                       -0.600249
# Life expectancy at birth (years)                                          0.911643
# Life expectancy at birth, female (years)                                  0.907971
# Life expectancy at birth, male (years)                                    0.905693
# Life expectancy index                                                     0.913585
# Mortality rate, female adult (per 1,000 people)                          -0.895857
# Mortality rate, infant (per 1,000 live births)                           -0.880151
# Mortality rate, male adult (per 1,000 people)                            -0.860146
# Mortality rate, under-five (per 1,000 live births)                       -0.880926
# Gross national income (GNI) per capita (2011 PP...                        0.883995
# Income index                                                              0.879525
# International inbound tourists (thousands)                                0.892455
# Exports and imports (% of GDP)                                            1.000000
# Foreign direct investment, net inflows (% of GDP)                         0.523016
# Private capital flows (% of GDP)                                         -0.223542
# Remittances, inflows (% of GDP)                                           0.612487
#
# indicator_name                                      Foreign direct investment, net inflows (% of GDP)  \
# indicator_name
# Human Development Index (HDI)                                                                0.515629
# Old-age (65 and older) dependency ratio (per 10...                                           0.199689
# Population ages 15–64 (millions)                                                             0.524954
# Population ages 65 and older (millions)                                                      0.428335
# Population under age 5 (millions)                                                            0.128006
# Total population (millions)                                                                  0.531209
# Urban population (%)                                                                         0.584027
# Young age (0-14) dependency ratio (per 100 peop...                                          -0.414378
# Education index                                                                              0.389217
# Expected years of schooling (years)                                                          0.339689
# Expected years of schooling, female (years)                                                  0.341728
# Expected years of schooling, male (years)                                                    0.168373
# Mean years of schooling (years)                                                              0.440388
# Mean years of schooling, female (years)                                                      0.467538
# Mean years of schooling, male (years)                                                        0.555596
# Population with at least some secondary educati...                                           0.521076
# Population with at least some secondary educati...                                           0.507654
# Share of seats in parliament (% held by women)                                               0.525078
# Infants lacking immunization, DPT (% of one-yea...                                          -0.615421
# Infants lacking immunization, measles (% of one...                                          -0.601519
# Life expectancy at birth (years)                                                             0.510189
# Life expectancy at birth, female (years)                                                     0.463308
# Life expectancy at birth, male (years)                                                       0.535943
# Life expectancy index                                                                        0.514191
# Mortality rate, female adult (per 1,000 people)                                             -0.586649
# Mortality rate, infant (per 1,000 live births)                                              -0.587600
# Mortality rate, male adult (per 1,000 people)                                               -0.626106
# Mortality rate, under-five (per 1,000 live births)                                          -0.584431
# Gross national income (GNI) per capita (2011 PP...                                           0.607106
# Income index                                                                                 0.620448
# International inbound tourists (thousands)                                                   0.578930
# Exports and imports (% of GDP)                                                               0.523016
# Foreign direct investment, net inflows (% of GDP)                                            1.000000
# Private capital flows (% of GDP)                                                            -0.458406
# Remittances, inflows (% of GDP)                                                              0.576800
#
# indicator_name                                      Private capital flows (% of GDP)  \
# indicator_name
# Human Development Index (HDI)                                              -0.180500
# Old-age (65 and older) dependency ratio (per 10...                          0.398810
# Population ages 15–64 (millions)                                           -0.235928
# Population ages 65 and older (millions)                                     0.071437
# Population under age 5 (millions)                                          -0.263647
# Total population (millions)                                                -0.201063
# Urban population (%)                                                       -0.285873
# Young age (0-14) dependency ratio (per 100 peop...                          0.066765
# Education index                                                            -0.008419
# Expected years of schooling (years)                                         0.002487
# Expected years of schooling, female (years)                                -0.065152
# Expected years of schooling, male (years)                                   0.158485
# Mean years of schooling (years)                                            -0.016228
# Mean years of schooling, female (years)                                     0.006987
# Mean years of schooling, male (years)                                      -0.174787
# Population with at least some secondary educati...                         -0.088527
# Population with at least some secondary educati...                         -0.314643
# Share of seats in parliament (% held by women)                             -0.210728
# Infants lacking immunization, DPT (% of one-yea...                          0.558532
# Infants lacking immunization, measles (% of one...                          0.533041
# Life expectancy at birth (years)                                           -0.166384
# Life expectancy at birth, female (years)                                   -0.081168
# Life expectancy at birth, male (years)                                     -0.216407
# Life expectancy index                                                      -0.168634
# Mortality rate, female adult (per 1,000 people)                             0.305823
# Mortality rate, infant (per 1,000 live births)                              0.262294
# Mortality rate, male adult (per 1,000 people)                               0.314916
# Mortality rate, under-five (per 1,000 live births)                          0.262360
# Gross national income (GNI) per capita (2011 PP...                         -0.367924
# Income index                                                               -0.387297
# International inbound tourists (thousands)                                 -0.055360
# Exports and imports (% of GDP)                                             -0.223542
# Foreign direct investment, net inflows (% of GDP)                          -0.458406
# Private capital flows (% of GDP)                                            1.000000
# Remittances, inflows (% of GDP)                                            -0.495890
#
# indicator_name                                      Remittances, inflows (% of GDP)
# indicator_name
# Human Development Index (HDI)                                              0.712734
# Old-age (65 and older) dependency ratio (per 10...                        -0.016595
# Population ages 15–64 (millions)                                           0.750528
# Population ages 65 and older (millions)                                    0.445198
# Population under age 5 (millions)                                          0.439301
# Total population (millions)                                                0.724490
# Urban population (%)                                                       0.787877
# Young age (0-14) dependency ratio (per 100 peop...                        -0.574736
# Education index                                                            0.596206
# Expected years of schooling (years)                                        0.576593
# Expected years of schooling, female (years)                                0.612262
# Expected years of schooling, male (years)                                  0.432846
# Mean years of schooling (years)                                            0.594741
# Mean years of schooling, female (years)                                    0.543310
# Mean years of schooling, male (years)                                      0.728041
# Population with at least some secondary educati...                         0.645176
# Population with at least some secondary educati...                         0.694259
# Share of seats in parliament (% held by women)                             0.714631
# Infants lacking immunization, DPT (% of one-yea...                        -0.441511
# Infants lacking immunization, measles (% of one...                        -0.575479
# Life expectancy at birth (years)                                           0.698456
# Life expectancy at birth, female (years)                                   0.617550
# Life expectancy at birth, male (years)                                     0.732392
# Life expectancy index                                                      0.695532
# Mortality rate, female adult (per 1,000 people)                           -0.732843
# Mortality rate, infant (per 1,000 live births)                            -0.768717
# Mortality rate, male adult (per 1,000 people)                             -0.752097
# Mortality rate, under-five (per 1,000 live births)                        -0.767352
# Gross national income (GNI) per capita (2011 PP...                         0.780443
# Income index                                                               0.799628
# International inbound tourists (thousands)                                 0.577470
# Exports and imports (% of GDP)                                             0.612487
# Foreign direct investment, net inflows (% of GDP)                          0.576800
# Private capital flows (% of GDP)                                          -0.495890
# Remittances, inflows (% of GDP)                                            1.000000
#
# [35 rows x 35 columns]

# %%
df_corr.corr().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, Human Development Index (HDI) to Remittances, inflows (% of GDP)
# Data columns (total 35 columns):
# Human Development Index (HDI)                                                      35 non-null float64
# Old-age (65 and older) dependency ratio (per 100 people ages 15-64)                35 non-null float64
# Population ages 15–64 (millions)                                                   35 non-null float64
# Population ages 65 and older (millions)                                            35 non-null float64
# Population under age 5 (millions)                                                  35 non-null float64
# Total population (millions)                                                        35 non-null float64
# Urban population (%)                                                               35 non-null float64
# Young age (0-14) dependency ratio (per 100 people ages 15-64)                      35 non-null float64
# Education index                                                                    35 non-null float64
# Expected years of schooling (years)                                                35 non-null float64
# Expected years of schooling, female (years)                                        35 non-null float64
# Expected years of schooling, male (years)                                          35 non-null float64
# Mean years of schooling (years)                                                    35 non-null float64
# Mean years of schooling, female (years)                                            35 non-null float64
# Mean years of schooling, male (years)                                              35 non-null float64
# Population with at least some secondary education, female (% ages 25 and older)    35 non-null float64
# Population with at least some secondary education, male (% ages 25 and older)      35 non-null float64
# Share of seats in parliament (% held by women)                                     35 non-null float64
# Infants lacking immunization, DPT (% of one-year-olds)                             35 non-null float64
# Infants lacking immunization, measles (% of one-year-olds)                         35 non-null float64
# Life expectancy at birth (years)                                                   35 non-null float64
# Life expectancy at birth, female (years)                                           35 non-null float64
# Life expectancy at birth, male (years)                                             35 non-null float64
# Life expectancy index                                                              35 non-null float64
# Mortality rate, female adult (per 1,000 people)                                    35 non-null float64
# Mortality rate, infant (per 1,000 live births)                                     35 non-null float64
# Mortality rate, male adult (per 1,000 people)                                      35 non-null float64
# Mortality rate, under-five (per 1,000 live births)                                 35 non-null float64
# Gross national income (GNI) per capita (2011 PPP $)                                35 non-null float64
# Income index                                                                       35 non-null float64
# International inbound tourists (thousands)                                         35 non-null float64
# Exports and imports (% of GDP)                                                     35 non-null float64
# Foreign direct investment, net inflows (% of GDP)                                  35 non-null float64
# Private capital flows (% of GDP)                                                   35 non-null float64
# Remittances, inflows (% of GDP)                                                    35 non-null float64
# dtypes: float64(35)
# memory usage: 9.8+ KB

# %%
#df_corr.corr()['Old-age (65 and older) dependency ratio (per 100 people ages 15-64)']['Human Development Index (HDI)']
df_corr.corr()['Old-age (65 and older) dependency ratio (per 100 people ages 15-64)']
# Out:
# indicator_name
# Human Development Index (HDI)                                                      0.561934
# Old-age (65 and older) dependency ratio (per 100 people ages 15-64)                1.000000
# Population ages 15–64 (millions)                                                   0.503312
# Population ages 65 and older (millions)                                            0.852551
# Population under age 5 (millions)                                                 -0.172902
# Total population (millions)                                                        0.563382
# Urban population (%)                                                               0.488395
# Young age (0-14) dependency ratio (per 100 people ages 15-64)                     -0.648901
# Education index                                                                    0.601153
# Expected years of schooling (years)                                                0.555902
# Expected years of schooling, female (years)                                        0.457335
# Expected years of schooling, male (years)                                          0.632865
# Mean years of schooling (years)                                                    0.666447
# Mean years of schooling, female (years)                                            0.669239
# Mean years of schooling, male (years)                                              0.556186
# Population with at least some secondary education, female (% ages 25 and older)    0.657209
# Population with at least some secondary education, male (% ages 25 and older)      0.206849
# Share of seats in parliament (% held by women)                                     0.578922
# Infants lacking immunization, DPT (% of one-year-olds)                             0.246796
# Infants lacking immunization, measles (% of one-year-olds)                        -0.095040
# Life expectancy at birth (years)                                                   0.592739
# Life expectancy at birth, female (years)                                           0.671352
# Life expectancy at birth, male (years)                                             0.553004
# Life expectancy index                                                              0.595330
# Mortality rate, female adult (per 1,000 people)                                   -0.450017
# Mortality rate, infant (per 1,000 live births)                                    -0.515161
# Mortality rate, male adult (per 1,000 people)                                     -0.448634
# Mortality rate, under-five (per 1,000 live births)                                -0.519880
# Gross national income (GNI) per capita (2011 PPP $)                                0.446016
# Income index                                                                       0.418747
# International inbound tourists (thousands)                                         0.732853
# Exports and imports (% of GDP)                                                     0.485950
# Foreign direct investment, net inflows (% of GDP)                                  0.199689
# Private capital flows (% of GDP)                                                   0.398810
# Remittances, inflows (% of GDP)                                                   -0.016595
# Name: Old-age (65 and older) dependency ratio (per 100 people ages 15-64), dtype: float64

# %%
df_corr.corr().keys()
# Out:
# Index(['Human Development Index (HDI)',
#        'Old-age (65 and older) dependency ratio (per 100 people ages 15-64)',
#        'Population ages 15–64 (millions)',
#        'Population ages 65 and older (millions)',
#        'Population under age 5 (millions)', 'Total population (millions)',
#        'Urban population (%)',
#        'Young age (0-14) dependency ratio (per 100 people ages 15-64)',
#        'Education index', 'Expected years of schooling (years)',
#        'Expected years of schooling, female (years)',
#        'Expected years of schooling, male (years)',
#        'Mean years of schooling (years)',
#        'Mean years of schooling, female (years)',
#        'Mean years of schooling, male (years)',
#        'Population with at least some secondary education, female (% ages 25 and older)',
#        'Population with at least some secondary education, male (% ages 25 and older)',
#        'Share of seats in parliament (% held by women)',
#        'Infants lacking immunization, DPT (% of one-year-olds)',
#        'Infants lacking immunization, measles (% of one-year-olds)',
#        'Life expectancy at birth (years)',
#        'Life expectancy at birth, female (years)',
#        'Life expectancy at birth, male (years)', 'Life expectancy index',
#        'Mortality rate, female adult (per 1,000 people)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'Mortality rate, male adult (per 1,000 people)',
#        'Mortality rate, under-five (per 1,000 live births)',
#        'Gross national income (GNI) per capita (2011 PPP $)', 'Income index',
#        'International inbound tourists (thousands)',
#        'Exports and imports (% of GDP)',
#        'Foreign direct investment, net inflows (% of GDP)',
#        'Private capital flows (% of GDP)', 'Remittances, inflows (% of GDP)'],
#       dtype='object', name='indicator_name')

# %%
len(df_corr.corr())
# Out:
# 35

# %%
#list containing sublist first value is key second is 
corr_x = []
for row in df_corr.corr():
    #corr_dict.update(row = df_corr.corr()[row])
    corr_x.append([row, df_corr.corr()[row]['Education index']])
corr_x.sort(key = 
             lambda corr: corr[1])
#gets rid of the correlation with the same feature
corr_x = corr_x[:-1]

print(corr_x)
# Out:
# [['Mortality rate, under-five (per 1,000 live births)', -0.8957301801890567], ['Mortality rate, infant (per 1,000 live births)', -0.8939259309172504], ['Young age (0-14) dependency ratio (per 100 people ages 15-64)', -0.8899332554336324], ['Mortality rate, female adult (per 1,000 people)', -0.8861986066255351], ['Mortality rate, male adult (per 1,000 people)', -0.8429782691031374], ['Infants lacking immunization, measles (% of one-year-olds)', -0.48092306585261724], ['Infants lacking immunization, DPT (% of one-year-olds)', -0.09184661807705537], ['Private capital flows (% of GDP)', -0.008418543365733009], ['Foreign direct investment, net inflows (% of GDP)', 0.38921651219583736], ['Population under age 5 (millions)', 0.5574842754950077], ['Remittances, inflows (% of GDP)', 0.5962059359960289], ['Old-age (65 and older) dependency ratio (per 100 people ages 15-64)', 0.6011532700567224], ['Population with at least some secondary education, male (% ages 25 and older)', 0.6400665480528305], ['Income index', 0.8327721048243784], ['Gross national income (GNI) per capita (2011 PPP $)', 0.8390745918238279], ['Population ages 65 and older (millions)', 0.8765526044291385], ['Urban population (%)', 0.8888898842113742], ['Exports and imports (% of GDP)', 0.8966646547725365], ['International inbound tourists (thousands)', 0.9076599940543973], ['Population ages 15–64 (millions)', 0.9097489860642315], ['Share of seats in parliament (% held by women)', 0.9107580497181826], ['Life expectancy at birth, male (years)', 0.9181478195469615], ['Total population (millions)', 0.9191307182781095], ['Mean years of schooling, male (years)', 0.9305040086140824], ['Life expectancy at birth (years)', 0.9314780436034437], ['Life expectancy index', 0.9350690218123131], ['Expected years of schooling, male (years)', 0.9453969782985058], ['Population with at least some secondary education, female (% ages 25 and older)', 0.9473475068134908], ['Life expectancy at birth, female (years)', 0.9481973326342565], ['Human Development Index (HDI)', 0.9568539316505816], ['Mean years of schooling, female (years)', 0.9696290590871636], ['Expected years of schooling, female (years)', 0.9718754613066345], ['Mean years of schooling (years)', 0.9848881294837082], ['Expected years of schooling (years)', 0.9870438737592965]]

# %%
# Out:
# Human Development Index (HDI)
# Old-age (65 and older) dependency ratio (per 100 people ages 15-64)
# Population ages 15–64 (millions)
# Population ages 65 and older (millions)
# Population under age 5 (millions)
# Total population (millions)
# Urban population (%)
# Young age (0-14) dependency ratio (per 100 people ages 15-64)
# Education index
# Expected years of schooling (years)
# Expected years of schooling, female (years)
# Expected years of schooling, male (years)
# Mean years of schooling (years)
# Mean years of schooling, female (years)
# Mean years of schooling, male (years)
# Population with at least some secondary education, female (% ages 25 and older)
# Population with at least some secondary education, male (% ages 25 and older)
# Share of seats in parliament (% held by women)
# Infants lacking immunization, DPT (% of one-year-olds)
# Infants lacking immunization, measles (% of one-year-olds)
# Life expectancy at birth (years)
# Life expectancy at birth, female (years)
# Life expectancy at birth, male (years)
# Life expectancy index
# Mortality rate, female adult (per 1,000 people)
# Mortality rate, infant (per 1,000 live births)
# Mortality rate, male adult (per 1,000 people)
# Mortality rate, under-five (per 1,000 live births)
# Gross national income (GNI) per capita (2011 PPP $)
# Income index
# International inbound tourists (thousands)
# Exports and imports (% of GDP)
# Foreign direct investment, net inflows (% of GDP)
# Private capital flows (% of GDP)
# Remittances, inflows (% of GDP)

# %%
df_corr.corr()['Human Development Index (HDI)']['Education index']
# Out:
# 0.9568539316505816

# %%
potential_indicators
# Out:
# [['Life expectancy at birth (years)', 0.9314780436034437],
#  ['Life expectancy index', 0.9350690218123131],
#  ['Expected years of schooling, male (years)', 0.9453969782985058],
#  ['Population with at least some secondary education, female (% ages 25 and older)',
#   0.9473475068134908],
#  ['Life expectancy at birth, female (years)', 0.9481973326342565],
#  ['Human Development Index (HDI)', 0.9568539316505816],
#  ['Mean years of schooling, female (years)', 0.9696290590871636],
#  ['Expected years of schooling, female (years)', 0.9718754613066345],
#  ['Mean years of schooling (years)', 0.9848881294837082],
#  ['Expected years of schooling (years)', 0.9870438737592965]]

# %%
def check_corr(df_corr, potential_indicators, target_feature):
    features_ex = [indicator[0] for indicator in potential_indicators]
    features_ex.remove(target_feature)
    for feature in features_ex:
        if df_corr.corr()[target_feature][feature] > 0.95:
            return False
    return True

potential_ret_val = []
for indicator_pair in potential_indicators:
    potential_ret_val.append(check_corr(df_corr, potential_indicators, indicator_pair[0]))
print(potential_ret_val)
#print([indicator[0] for indicator in potential_indicators])
#print([indicator[0] for indicator in potential_indicators].remove('Expected years of schooling (years)'))
#check_corr(df_corr, potential_indicators, 'Expected years of schooling (years)')
#for indicator_pair in potential_indicators:
# Out:
# [False, False, False, False, False, False, False, False, False, False]

# %%
df_corr.corr()['Mean years of schooling (years)']['Life expectancy at birth (years)']
# Out:
# 0.9499836748084022
